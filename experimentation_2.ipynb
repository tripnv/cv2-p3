# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import copy

# %%
auxiliary_path = 'auxiliary_images/'
training_path = 'train/Task2/'

# %%
config_imgs = []
for img_path in os.listdir(auxiliary_path):
    config_imgs.append(cv2.imread(auxiliary_path + img_path))

# %%
imgs, confs_ = [], []
for f in sorted(os.listdir(training_path)):
    if f[-4:] == '.jpg':
        fname = f.split('.')[0]
        imgs.append(cv2.imread(training_path + fname + '.jpg'))
        with open(training_path + fname + '.txt', 'r') as rf:
            confs_.append(rf.read())

# %%
len(imgs)
# Out:
# 25

# %%
fig, axs = plt.subplots(nrows=5, ncols=5, figsize = (100,100))
# fig.tight_layout()

i = 0
for img, conf_ in copy.deepcopy(zip(imgs, confs_)):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(img)
    plt.title(f"{i}:\n" + conf_)
    
    i += 1

# %%
lower_rings = (15,70,50)
upper_rings = (180,255,255)

template_ = copy.deepcopy(config_imgs[3])
hsv_img = cv2.cvtColor(template_, cv2.COLOR_BGR2HSV)

mask_rings = cv2.inRange(hsv_img, lower_rings, upper_rings)
# mask_rings = cv2.dilate(mask_rings, (3,3), iterations=2)
min_area_red = 20 * 20
contours_rings, _ = cv2.findContours(mask_rings, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
contours_rings = [cnt for cnt in contours_rings if cv2.contourArea(cnt) > min_area_red]



cv2.drawContours(template_, contours_rings, -1, (255,0,0), 3)
plt.figure(figsize = (50,50))
plt.imshow(mask_rings)

# %%
lower_rings = (0,95,30)
upper_rings = (180,255,255)

template_ = copy.deepcopy(config_imgs[3])
hsv_img = cv2.cvtColor(template_, cv2.COLOR_BGR2HSV)

mask_rings = cv2.inRange(hsv_img, lower_rings, upper_rings)

# mask_rings = cv2.morphologyEx(mask_rings, cv2.MORPH_CLOSE, (3,3),5)
# mask_rings = cv2.erode(mask_rings, (25,25))
mask_rings = cv2.dilate(mask_rings, (3,25), iterations = 5)

min_area_red = 20 * 20
contours_rings, _ = cv2.findContours(mask_rings, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
contours_rings = [cnt for cnt in contours_rings if cv2.contourArea(cnt) > min_area_red]



cv2.drawContours(template_, contours_rings, -1, (255,0,0), 3)
plt.figure(figsize = (50,50))
plt.imshow(mask_rings)

# %%
lower_green = (0, 87, 0)
upper_green = (180,255,110)

lower_red = (0, 48, 100)
upper_red = (180, 255, 255)


template_ = copy.deepcopy(config_imgs[3])
# blurred_img = cv2.GaussianBlur(template_, (7,7), cv2.BORDER_DEFAULT)
hsv_img = cv2.cvtColor(template_, cv2.COLOR_BGR2HSV)

mask_green = cv2.inRange(hsv_img, lower_green, upper_green)
mask_red = cv2.inRange(hsv_img, lower_red, upper_red)
# mask_rings = cv2.morphologyEx(mask_rings, cv2.MORPH_CLOSE, (3,3),5)
# mask_rings = cv2.erode(mask_rings, (25,25))
# mask_rings = cv2.dilate(mask_rings, (3,25), iterations = 5)

mask = mask_green + mask_red

min_area_red = 20 * 20
contours_rings, _ = cv2.findContours(mask, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
contours_rings = [cnt for cnt in contours_rings if cv2.contourArea(cnt) > min_area_red]




cv2.drawContours(template_, contours_rings, -1, (255,0,0), 3)
plt.figure(figsize = (50,50))

ax1 = plt.subplot(121)
ax2 = plt.subplot(122)

ax1.imshow(mask)
ax2.imshow(template_)

# %%
slices = {key:{"left":None, 'right': None} for key in range(1,20) }

# %%
slices[20] = {'left': (1133, 783), 'right': (1397, 807)}
slices[1] = {'left': (1397, 807), 'right': (1628, 930)}
slices[18] = {'left': (1628, 930), 'right': (1810, 1121)}
slices[4] = {'left': (1810, 1121), 'right': (1942, 1367)}
slices[13] = {'left': (1942, 1367), 'right': (2005, 1626)}
slices[6] = {'left': (2005, 1626), 'right': (2017, 1900)}
slices[10] = {'left': (2017, 1900), 'right': (1977, 2174)}
slices[15] = {'left': (1977, 2174), 'right': (1880, 2429)}
slices[2] = {'left': (1880, 2429), 'right': (1731, 2660)}
slices[17] = {'left': (1731, 2660), 'right': (1508, 2846)}
slices[3] = {'left':  (1508, 2846), 'right': (1262, 2940)}
slices[19] = {'left': (1262, 2940), 'right': (982, 2932)}
slices[7] = {'left': (982, 2932), 'right': (710, 2786)}
slices[16] = {'left':  (710, 2786), 'right': (475, 2510)}
slices[8] = {'left': (475, 2510), 'right': (350, 2183)}
slices[11] = {'left':  (350, 2183), 'right': (315, 1782)}
slices[14] = {'left': (315, 1782), 'right': (420, 1406)}
slices[9] = {'left': (420, 1406), 'right': (600, 1085)}
slices[12] = {'left': (600, 1085), 'right': (860, 870)}
slices[5] = {'left': (860, 870), 'right': (1133, 783)}

# %%
lower_green_red = (0, 60, 40)
upper_green_red = (180,255,255)

template_ = copy.deepcopy(config_imgs[3])
hsv_img = cv2.cvtColor(template_, cv2.COLOR_BGR2HSV)

mask = cv2.inRange(hsv_img, lower_green_red, upper_green_red)
mask = cv2.erode(mask, (5,5), iterations=5)
mask = cv2.GaussianBlur(mask, (15, 15), cv2.BORDER_CONSTANT)
# mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE,(15,15), iterations = 25)
min_area_red = 50 * 50
contours_rings, _ = cv2.findContours(mask, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
contours_rings = [cnt for cnt in contours_rings if cv2.contourArea(cnt) > min_area_red]

ellipsis_ = []
for cnt in contours_rings:
    ellipse = cv2.fitEllipse(cnt)
    ellipsis_.append(ellipse)



empty = np.zeros_like(mask)
print(ellipsis_[0])

for el in ellipsis_:
    
    cv2.ellipse(template_, el,(0,255,0),2)

cv2.circle(template_, (int(ellipsis_[0][0][0]), int(ellipsis_[0][0][1])), 15, color = (255,255,0), thickness = -1)
cv2.circle(template_, slices[1]['left'], 15, color = (255,255,0), thickness = -1)
cv2.circle(template_, (1230, 641), 15, color = (255,255,0), thickness = -1)


for idx, endpoint in slices.items():
        cv2.line(template_, (int(ellipsis_[0][0][0]), int(ellipsis_[0][0][1])), endpoint['left'], color = (255, 0, 255), thickness = 3)

# cv2.drawContours(template_, contours_rings, -1, (255,0,0), 3)
plt.figure(figsize = (50,50))

ax1 = plt.subplot(121)
ax2 = plt.subplot(122)

ax1.imshow(empty)
ax2.imshow(template_)

# %%
fig, axs = plt.subplots(nrows=5, ncols=5, figsize = (100,100))
# fig.tight_layout()


lower = (5, 20, 40)
upper = (100,255,255)
kernel = np.ones((3, 3), np.uint8)
i = 0
for img, conf_ in copy.deepcopy(zip(imgs, confs_)):
    ax = plt.subplot(5, 5, i + 1)
    
    for el in ellipsis_:
    
        cv2.ellipse(img, el,(0,0,255),2)
    
    plt.imshow(img)
    plt.title(f"{i}:\n" + conf_)
    
    i += 1

# %%
fig, axs = plt.subplots(nrows=5, ncols=5, figsize = (100,100))
# fig.tight_layout()


lower = (0, 20, 52)
upper = (44,200,255)
kernel = np.ones((3, 3), np.uint8)
i = 0
for img, conf_ in copy.deepcopy(zip(imgs, confs_)):
    ax = plt.subplot(5, 5, i + 1)

    hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv_img, lower, upper)
    
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=1)
    contours, hierarchy = cv2.findContours(mask, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

    filtered_cnt = []
    min_area = 40 * 50

    for cnt in contours[1:]:
        area = cv2.contourArea(cnt)
        if area > min_area:
            filtered_cnt.append(cnt)

    print(img.shape[:2])
    
    for cnt in filtered_cnt:
        max_x = img.shape[1]
        leftmost = None
        for point in cnt:

            if max_x > point[0][0]:
                max_x = point[0][0]
                leftmost = point[0]

        cv2.circle(img, leftmost, 10, (255, 255,0 ), -1)

    # cv2.drawContours(img, delimiters, -1, (255,0,0), 3)
    
    plt.imshow(img)
    plt.title(f"{i}:\n" + conf_)
    
    i += 1

# %%
fig, axs = plt.subplots(nrows=5, ncols=5, figsize = (100,100))
# fig.tight_layout()

template = copy.deepcopy()
lower = (0, 20, 52)
upper = (44,200,255)
kernel = np.ones((3, 3), np.uint8)
i = 0
for img, conf_ in copy.deepcopy(zip(imgs, confs_)):
    ax = plt.subplot(5, 5, i + 1)
    
    hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv_img, lower, upper)
    
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=1)
    contours, hierarchy = cv2.findContours(mask, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

    filtered_cnt = []
    min_area = 40 * 50

    for cnt in contours[1:]:
        area = cv2.contourArea(cnt)
        if area > min_area:
            filtered_cnt.append(cnt)

    print(img.shape[:2])
    
    for cnt in filtered_cnt:
        max_x = img.shape[1]
        leftmost = None
        for point in cnt:

            if max_x > point[0][0]:
                max_x = point[0][0]
                leftmost = point[0]

        cv2.circle(img, leftmost, 10, (255, 255,0 ), -1)

    # cv2.drawContours(img, delimiters, -1, (255,0,0), 3)
    
    plt.imshow(img)
    plt.title(f"{i}:\n" + conf_)
    
    i += 1
